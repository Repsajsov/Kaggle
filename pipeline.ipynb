# %%
from sklearn.pipeline import Pipeline, make_pipeline, FeatureUnion, make_union
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from skrub import SelectCols

class RegexEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, column, pattern, cast_type=None):
        pass

    def fit(self, X, y=None):
        pass

    def transform(self, X):
        X = np.asarray(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 5
#       2 from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
#       3 from skrub import SelectCols
# ----> 5 class RegexEncoder(BaseEstimator, TransformerMixin):
#       6     def __init__(self, column, pattern, cast_type=None):
#       7         pass
#
# NameError: name 'BaseEstimator' is not defined

# %%
np.asarray(df)
# Out:
# array([[1, 0, 3, ..., 7.25, None, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, None, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, None, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, None, 'Q']], shape=(891, 12), dtype=object)

# %%
import polars as pl
import pandas as pd
import numpy as np
df = pl.read_csv("../Data/Titanic/train.csv")

df.head()
# Out:
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# │ 3           ┆ 1        ┆ 3      ┆ Heikkinen, Miss.  ┆ … ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina             ┆   ┆ 3101282   ┆         ┆       ┆          │
# │ 4           ┆ 1        ┆ 1      ┆ Futrelle, Mrs.    ┆ … ┆ 113803    ┆ 53.1    ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath (…  ┆   ┆           ┆         ┆       ┆          │
# │ 5           ┆ 0        ┆ 3      ┆ Allen, Mr.        ┆ … ┆ 373450    ┆ 8.05    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ William Henry     ┆   ┆           ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴───────────────────┴───┴───────────┴─────────┴───────┴──────────┘

# %%
pipeline = make_pipeline(
    make_union(
        (SelectCols(['Survived', 'Pclass', 'SibSp', 'Parch'])),
        (make_pipeline(
            SelectCols(['Age', 'Fare']), 
            StandardScaler()
        )),
        (make_pipeline(
            SelectCols(['Sex', 'Embarked']), 
            OneHotEncoder(sparse_output=False, drop='first')
        )),
    )
)
# pipeline.fit_transform(df)
pipeline
# Out:
# Pipeline(steps=[('featureunion',
#                  FeatureUnion(transformer_list=[('selectcols',
#                                                  SelectCols(cols=['Survived',
#                                                                   'Pclass',
#                                                                   'SibSp',
#                                                                   'Parch'])),
#                                                 ('pipeline-1',
#                                                  Pipeline(steps=[('selectcols',
#                                                                   SelectCols(cols=['Age',
#                                                                                    'Fare'])),
#                                                                  ('standardscaler',
#                                                                   StandardScaler())])),
#                                                 ('pipeline-2',
#                                                  Pipeline(steps=[('selectcols',
#                                                                   SelectCols(cols=['Sex',
#                                                                                    'Embarked'])),
#                                                                  ('onehotencoder',
#                                                                   OneHotEncoder(drop='first',
#                                                                                 sparse_output=False))]))]))])
